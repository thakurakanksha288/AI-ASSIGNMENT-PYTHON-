# %% [markdown]
# <a href="https://colab.research.google.com/github/thakurakanksha288/AI-ASSIGNMENT-PYTHON-/blob/main/jupyter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello world")
# Out:
# hello world

# %%
#adding comment like this

# %%
##hello world##

# %%
#making calculator
x=input("enter the first number:")
y=input("enter the second number:")
operation=input.lower(("enter the operation you want to perform:(sum/diffrence/divide/multiply)"))
if operation=="sum":
  print(x+y)
elif operation=="diffrence":
  print(x-y)
elif operation=="divide":
  print(x/y)
else
  print(x*y)

# %%
#use of underscore - helps us gets the previous output

# %%
#while loop
count=0
while(count<10)
  count=count+1
  print("good night python")

# %%
#for loop
fruits=["apple","mango"]
for f in fruits:
  print("f")

# %%
#for loop in range
for i in range(0,100)
  print(i)

# %%
#if - else
a = 2
b = 4

if a<b:
  print(f"'{a},'less than '{b}'")
else:
  print(f"'{b},'less than '{a}'")

# %%
#lists[]

list=[1,"winning day",20,19,63]
print(list)
print(list[0])
print(len(list))
list.append("race day")
list.insert(20,"happy innings")

# %%
#TURPLES
var=('python','geeks','for','geeks')
print(var)
turple1=(1,2,3)
turple2=(4,5,6)
print(turple1[1::])
print(turple2[::-1])

# %%
#SETS

a={1,'s',6.9,"school"}
s=len(a)
print(s)
a.add(90)
a.update([2,"abc",36])
a.remove(6.9)
a.discard('s')
b={1,2,3,4,5,6,7,8,9}
a.union(b)
print(a&b)
print(a-b)
c=frozenset(a)
print(c)

# %%
# DICTIONARIES

dics={'a':'10256','b':'98764','c':'6985496'}
print(dics)
print(dics[2])

# %%
#TYPECASTING

a=int(1.5)
b=float(1)

# %%
#Print even numbers till 100
for i in range(2, 101, 2):
    print(i)

# %%
#Multiplication table (input from user)

num = int(input("Enter a number: "))

for i in range(1, 11):
    print(num, "x", i, "=", num * i)

# %%
#Factorial of a number
num = int(input("Enter a number: "))
fact = 1

for i in range(1, num + 1):
    fact *= i

print("Factorial is:", fact)

# %%
#Check whether a given number is prime or not
num = int(input("Enter a number: "))

if num <= 1:
    print("Not a prime number")
else:
    for i in range(2, num):
        if num % i == 0:
            print("Not a prime number")
            break
    else:
        print("Prime number")

# %%
#astrostrong number
num = int(input("Enter a number: "))
temp = num
sum = 0

while temp > 0:
    digit = temp % 10
    sum += digit ** 3
    temp //= 10

if sum == num:
    print("Armstrong number")
else:
    print("Not an Armstrong number")

# %%
#Class and Object example

class Student:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def display(self):
        print("Name:", self.name)
        print("Age:", self.age)

# object creation
s1 = Student("Akanksha", 20)
s1.display()
